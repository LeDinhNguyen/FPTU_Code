# %%
! pip install --force-reinstall ibm_db==3.1.0 ibm_db_sa==0.3.3
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.3/797.3 kB 6.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 57.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.7/613.7 kB 44.8 MB/s eta 0:00:00
# ...
#   Created wheel for ibm_db: filename=ibm_db-3.1.0-cp310-cp310-linux_x86_64.whl size=41721380 sha256=3d4b48fe21f499c86292062642e39ca31c42db29ee5080f7787c8fefaf4333c5
#   Stored in directory: /root/.cache/pip/wheels/50/d7/3d/cf01ca490baa2f299aca0c791a2a5708d9b9676608374e2f31
# ...
#   Created wheel for ibm_db_sa: filename=ibm_db_sa-0.3.3-py3-none-any.whl size=27421 sha256=8471e5018015591a20766613bb107ff1c2060a75f347f6c285452da9cde06dc1
# ...

# %%
! pip uninstall sqlalchemy==1.4 -y && pip install sqlalchemy==1.3.24
# Out:
# Found existing installation: SQLAlchemy 2.0.21
# Uninstalling SQLAlchemy-2.0.21:
#   Successfully uninstalled SQLAlchemy-2.0.21
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 74.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.3.24-cp310-cp310-linux_x86_64.whl size=1252700 sha256=de82a48dbe437eea80f024be1edd7cd50657d6aa6c2b24b42727052061dc1ab5
#   Stored in directory: /root/.cache/pip/wheels/27/51/b3/3481e88d5a5ba95dd4aafedc9316774d941c4ba61cfb93add8
# Successfully built sqlalchemy
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.3.24 which is incompatible.
# ...

# %%
! pip install ipython-sql
# Out:
# ...
#   Using cached SQLAlchemy-2.0.21-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 24.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.3.24
#     Uninstalling SQLAlchemy-1.3.24:
#       Successfully uninstalled SQLAlchemy-1.3.24
# ...

# %%
import ibm_db
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-fe3bb08c8a05> in <cell line: 1>()
# ----> 1 import ibm_db
#
# ModuleNotFoundError: No module named 'ibm_db'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
dsn_hostname = "54a2f15b-5c0f-46df-8954-7e38e612c2bd.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud" # e.g.: "54a2f15b-5c0f-46df-8954-7e38e612c2bd.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud"
dsn_uid = "lpg30698"        # e.g. "abc12345"
dsn_pwd = "ZKnImiyfGqvzksPe"      # e.g. "7dBZ3wWt9XN6$o0J"

dsn_driver = "{IBM DB2 ODBC DRIVER}"
dsn_database = "bludb"            # e.g. "BLUDB"
dsn_port = "32733"                # e.g. "32733"
dsn_protocol = "TCPIP"            # i.e. "TCPIP"
dsn_security = "SSL"              #i.e. "SSL"

# %%
#Create database connection
#DO NOT MODIFY THIS CELL. Just RUN it with Shift + Enter
dsn = (
    "DRIVER={0};"
    "DATABASE={1};"
    "HOSTNAME={2};"
    "PORT={3};"
    "PROTOCOL={4};"
    "UID={5};"
    "PWD={6};"
    "SECURITY={7};").format(dsn_driver, dsn_database, dsn_hostname, dsn_port, dsn_protocol, dsn_uid, dsn_pwd,dsn_security)

try:
    conn = ibm_db.connect(dsn, "", "")
    print ("Connected to database: ", dsn_database, "as user: ", dsn_uid, "on host: ", dsn_hostname)

except:
    print ("Unable to connect: ", ibm_db.conn_errormsg() )
# Out:
# Connected to database:  bludb as user:  lpg30698 on host:  54a2f15b-5c0f-46df-8954-7e38e612c2bd.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud

# %%
#Lets first drop the table INSTRUCTOR in case it exists from a previous attempt
dropQuery = "drop table INSTRUCTOR"

#Now execute the drop statment
dropStmt = ibm_db.exec_immediate(conn, dropQuery)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-83413676a2ca> in <cell line: 5>()
#       3
#       4 #Now execute the drop statment
# ----> 5 dropStmt = ibm_db.exec_immediate(conn, dropQuery)
#
# NameError: name 'conn' is not defined

# %%
#Construct the Create Table DDL statement - replace the ... with rest of the statement
createQuery = "create table INSTRUCTOR(ID INTEGER PRIMARY KEY NOT NULL, \
FNAME VARCHAR(20), LNAME VARCHAR(20), CITY VARCHAR(20), CCODE CHAR(2))"

#Now fill in the name of the method and execute the statement
createStmt = ibm_db.exec_immediate(conn, createQuery)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6ed7f8dd1b2c> in <cell line: 6>()
#       4
#       5 #Now fill in the name of the method and execute the statement
# ----> 6 createStmt = ibm_db.exec_immediate(conn, createQuery)
#
# NameError: name 'conn' is not defined

# %%
#Construct the query - replace ... with the insert statement
insertQuery = "insert into INSTRUCTOR values (1, 'Rav', 'Ahuja', 'TORONTO', 'CA')"

insertStmt = ibm_db.exec_immediate(conn, insertQuery)

# %%
#replace ... with the insert statement that inerts the remaining two rows of data
insertQuery2 = "insert into INSTRUCTOR values (2, 'Raul', 'Chong', 'Markham', 'CA'),\
(3, 'Hima', 'Vasudevan', 'Chicago', 'US')"

insertStmt2 = ibm_db.exec_immediate(conn, insertQuery2)

# %%
#Construct the query that retrieves all rows from the INSTRUCTOR table
selectQuery = "select * from INSTRUCTOR"

#Execute the statement
selectStmt = ibm_db.exec_immediate(conn, selectQuery)

#Fetch the Dictionary (for the first row only) - replace ... with your code
ibm_db.fetch_both(selectStmt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-54c06ad06678> in <cell line: 5>()
#       3
#       4 #Execute the statement
# ----> 5 selectStmt = ibm_db.exec_immediate(conn, selectQuery)
#       6
#       7 #Fetch the Dictionary (for the first row only) - replace ... with your code
#
# NameError: name 'conn' is not defined

# %%
#Fetch the rest of the rows and print the ID and FNAME for those rows
while ibm_db.fetch_row(selectStmt) != False:
   print (" ID:",  ibm_db.result(selectStmt, 0), " FNAME:",  ibm_db.result(selectStmt, "FNAME"))
# Out:
#  ID: 2  FNAME: Raul
#  ID: 3  FNAME: Hima

# %%
import ibm_db

# %%
import ibm_db
ibm_db.connect("DATABASE=bludb;HOSTNAME=54a2f15b-5c0f-46df-8954-7e38e612c2bd.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud;PORT=32733;PROTOCOL=TCPIP;UID=lpg30698;PWD=ZKnImiyfGqvzksPe;", "", "")

# %%
stmt = ibm_db.exec_immediate(conn,"select ELEMENTARY__MIDDLE__OR_HIGH_SCHOOL from CHICAGO_TAB")

# %%
ibm_db.fetch_both(stmt)
# Out:
# {'ELEMENTARY__MIDDLE__OR_HIGH_SCHOOL': 'ES', 0: 'ES'}

# %%
import pandas
import ibm_db_dbi

# %%
pconn = ibm_db_dbi.Connection(conn)

# %%
df = pandas.read_sql('select ELEMENTARY__MIDDLE__OR_HIGH_SCHOOL from CHICAGO_TAB',pconn)
# Out:
# <ipython-input-20-87d024597937>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pandas.read_sql('select ELEMENTARY__MIDDLE__OR_HIGH_SCHOOL from CHICAGO_TAB',pconn)

# %%
df
# Out:
#     ELEMENTARY__MIDDLE__OR_HIGH_SCHOOL
# 0                                   ES
# 1                                   ES
# 2                                   ES
# 3                                   ES
# 4                                   HS
# ..                                 ...
# 561                                 ES
# 562                                 ES
# 563                                 ES
# 564                                 ES
# 565                                 HS
#
# [566 rows x 1 columns]

# %%
df = pandas.read_sql('select * from CHICAGO_TAB',pconn)
# Out:
# <ipython-input-22-645f9c8ab0ec>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pandas.read_sql('select * from CHICAGO_TAB',pconn)

# %%
df
# Out:
#      SCHOOL_ID                                     NAME_OF_SCHOOL  \
# 0       610038                  Abraham Lincoln Elementary School
# 1       610281  Adam Clayton Powell Paideia Community Academy ...
# 2       610185                Adlai E Stevenson Elementary School
# 3       609993                    Agustin Lara Elementary Academy
# 4       610513                      Air Force Academy High School
# ..         ...                                                ...
# 561     610172                William T Sherman Elementary School
# 562     609844                 William W Carter Elementary School
# 563     610088                Wolfgang A Mozart Elementary School
# 564     609977               Woodlawn Community Elementary School
# 565     610392                 World Language Academy High School
#
#     ELEMENTARY__MIDDLE__OR_HIGH_SCHOOL         STREET_ADDRESS     CITY STATE  \
# 0                                   ES        615 W Kemper Pl  Chicago    IL
# ...

# %%
df.describe(include='all')
# Out:
#             SCHOOL_ID                     NAME_OF_SCHOOL  \
# count      566.000000                                566
# unique            NaN                                566
# top               NaN  Abraham Lincoln Elementary School
# freq              NaN                                  1
# mean    609681.791519                                NaN
# std       8831.060946                                NaN
# min     400018.000000                                NaN
# 25%     609873.250000                                NaN
# 50%     610052.500000                                NaN
# 75%     610212.750000                                NaN
# max     610544.000000                                NaN
#
#        ELEMENTARY__MIDDLE__OR_HIGH_SCHOOL      STREET_ADDRESS     CITY STATE  \
# count                                 566                 566      566   566
# unique                                  3                 550        1     1
# ...

# %% [markdown]
# #### Question 1. Calculate the total number of students in each grade level.

# %%
qo = pandas.read_sql('select ELEMENTARY__MIDDLE__OR_HIGH_SCHOOL, count(*) as total_number_of_students from CHICAGO_TAB group by ELEMENTARY__MIDDLE__OR_HIGH_SCHOOL',pconn)
# Out:
# <ipython-input-29-8cad97b60df9>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   qo = pandas.read_sql('select ELEMENTARY__MIDDLE__OR_HIGH_SCHOOL, count(*) as total_number_of_students from CHICAGO_TAB group by ELEMENTARY__MIDDLE__OR_HIGH_SCHOOL',pconn)

# %%
qo
# Out:
#   ELEMENTARY__MIDDLE__OR_HIGH_SCHOOL  TOTAL_NUMBER_OF_STUDENTS
# 0                                 ES                       462
# 1                                 HS                        93
# 2                                 MS                        11

# %% [markdown]
# #### Question 3. Calculate average of AVERAGE_STUDENT_ATTENDANCE of 10 schools with least SAFETY_SCORE

# %%
qt = pandas.read_sql(
    'SELECT AVG(CAST(REPLACE(AVERAGE_STUDENT_ATTENDANCE, \'%\', \'\') AS DECIMAL(5, 2))) AS average_attendance '
    'FROM (SELECT Name_OF_SCHOOL, AVERAGE_STUDENT_ATTENDANCE, SAFETY_SCORE '
          'FROM CHICAGO_TAB '
          'ORDER BY SAFETY_SCORE ASC '
          'LIMIT 10) AS subquery;', pconn)
# Out:
# <ipython-input-65-c949ab019a57>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   qt = pandas.read_sql(

# %%
qt
# Out:
#    AVERAGE_ATTENDANCE
# 0               89.12

# %% [markdown]
# #### Question 4. Find 10 High school with highest College_Eligibility__ score.

# %%
import pandas as pd

# SQL query to select the top 10 schools with the highest College_Eligibility_Score
qf = pd.read_sql(
    'SELECT Name_OF_SCHOOL, CAST(College_Eligibility__ AS FLOAT) AS College_Eligibility_Score '
    'FROM CHICAGO_TAB '
    'WHERE COLLEGE_ELIGIBILITY__ NOT LIKE \'%NDA%\' '  # Use single quotes to escape %
    'ORDER BY College_Eligibility_Score DESC '
    'LIMIT 10',
    pconn
)
# Out:
# <ipython-input-46-cfe3d21ae316>:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   qf = pd.read_sql(

# %%
qf
# Out:
#                                       NAME_OF_SCHOOL  \
# 0          Northside College Preparatory High School
# 1      Walter Payton College Preparatory High School
# 2                 Whitney M Young Magnet High School
# 3      William Jones College Preparatory High School
# 4                Albert G Lane Technical High School
# 5              Northside Learning Center High School
# 6       Jacqueline B Vaughn Occupational High School
# 7                           Lincoln Park High School
# 8  Gwendolyn Brooks College Preparatory Academy H...
# 9     DeVry University Advantage Academy High School
#
#    COLLEGE_ELIGIBILITY_SCORE
# 0                       98.0
# 1                       96.4
# 2                       89.0
# 3                       83.3
# 4                       67.9
# 5                       66.7
# 6                       55.6
# 7                       53.6
# 8                       51.1
# 9                       40.6

# %%
pip install openpyxl

# %%
# !mamba install openpyxl==3.0.9 -y
# Out:
# /bin/bash: line 1: mamba: command not found

# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library

# %%
# !pip3 install folium==0.5.0
import folium

print('Folium installed and imported!')
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.2/79.2 kB 1.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for folium: filename=folium-0.5.0-py3-none-any.whl size=76115 sha256=7940e08d757938d2ae204367acf308e4ae82aa4fdd87ff9677350afa7da5b397
#   Stored in directory: /root/.cache/pip/wheels/f2/b2/ba/4d13deef259f0f71ed55c132ea89c37a5731d342858e46f42e
# Successfully built folium
# ...
#   Attempting uninstall: folium
#     Found existing installation: folium 0.14.0
#     Uninstalling folium-0.14.0:
#       Successfully uninstalled folium-0.14.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.17.6 requires folium>=0.9.1, but you have folium 0.5.0 which is incompatible.
# geemap 0.26.0 requires folium>=0.13.0, but you have folium 0.5.0 which is incompatible.
# ...
# Folium installed and imported!

# %%
# define the world map
world_map = folium.Map()

# display world map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### CHICAGO MAP

# %%
# define the Chicago map with a higher zoom level
chicago_map = folium.Map(location=[41.84969736, -87.6252787], zoom_start=12)

# display Chicago map
chicago_map

#save Chicago map into .html
chicago_map.save('chicago.html')

# %%
folium.Marker([42.01017628, -87.68446868])

# %% [markdown]
# #### Figure out all school destination

# %%
loc = pd.read_sql('SELECT REPLACE(REPLACE(Location, \'(\', \'\'), \')\', \'\') as des FROM CHICAGO_TAB', pconn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-a5c327d96f45> in <cell line: 1>()
# ----> 1 loc = pd.read_sql('SELECT REPLACE(REPLACE(Location, \'(\', \'\'), \')\', \'\') as des FROM CHICAGO_TAB', pconn)
#
# NameError: name 'pconn' is not defined

# %%
loc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-98eacc010565> in <cell line: 1>()
# ----> 1 loc
#
# NameError: name 'loc' is not defined

# %%
import folium
import pandas as pd

# Define the Chicago map with a higher zoom level
chicago_map = folium.Map(location=[41.84969736, -87.6252787], zoom_start=12)

# Assuming you have DataFrames 'kd' and 'vd' with latitude and longitude data
# Replace 'LATITUDE' and 'LONGITUDE' with your actual column names

# Iterate through rows in 'kd' and 'vd' DataFrames and add markers
for index, row in kd.iterrows():
    latitude = row['LATITUDE']  # Replace 'LATITUDE' with your actual column name
    longitude = vd.iloc[index]['LONGITUDE']  # Replace 'LONGITUDE' with your actual column name

    # Create markers with latitude and longitude
    folium.Marker([latitude, longitude]).add_to(chicago_map)

# Save the Chicago map to an HTML file
chicago_map.save('chicago.html')

# Display the Chicago map (if running in a Jupyter Notebook or interactive environment)
chicago_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-1469700a5ff8> in <cell line: 11>()
#       9
#      10 # Iterate through rows in 'kd' and 'vd' DataFrames and add markers
# ---> 11 for index, row in kd.iterrows():
#      12     latitude = row['LATITUDE']  # Replace 'LATITUDE' with your actual column name
#      13     longitude = vd.iloc[index]['LONGITUDE']  # Replace 'LONGITUDE' with your actual column name
#
# NameError: name 'kd' is not defined

# %%
ibm_db.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-d868d87f44b1> in <cell line: 1>()
# ----> 1 ibm_db.close()
#
# NameError: name 'ibm_db' is not defined
