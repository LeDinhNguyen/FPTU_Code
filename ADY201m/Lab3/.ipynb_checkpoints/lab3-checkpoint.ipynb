# %%
import pandas
import ibm_db_dbi
import ibm_db
from sqlalchemy import create_engine

# %%
dsn_hostname = "1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud"
dsn_uid = "xkk84284"        # e.g. "abc12345"
dsn_pwd = "QdRxktEwkW0eOMFE"      # e.g. "7dBZ3wWt9XN6$o0J"

dsn_driver = "{IBM DB2 ODBC DRIVER}"
dsn_database = "bludb"            # e.g. "BLUDB"
dsn_port = "32286"                # e.g. "32733"
dsn_protocol = "TCPIP"            # i.e. "TCPIP"
dsn_security = "SSL"          #i.e. "SSL"

# %%
db2_connection_string = (
    f'db2://{dsn_uid}:{dsn_pwd}@{dsn_hostname}:{dsn_port}/{dsn_database}'
    ':SECURITY=SSL;PROTOCOL=TCP/IP;'
)

# %%
engine = create_engine(db2_connection_string)
connection = engine.connect()

# %%
# Create database connection
# DO NOT MODIFY THIS CELL. Just RUN it with Shift + Enter
dsn = (
    "DRIVER={0};"
    "DATABASE={1};"
    "HOSTNAME={2};"
    "PORT={3};"
    "PROTOCOL={4};"
    "UID={5};"
    "PWD={6};"
    "SECURITY={7};").format(dsn_driver, dsn_database, dsn_hostname, dsn_port, dsn_protocol, dsn_uid, dsn_pwd,dsn_security)

try:
    conn = ibm_db.connect(dsn, "", "")
    print ("Connected to database: ", dsn_database, "as user: ", dsn_uid, "on host: ", dsn_hostname)

except:
    print ("Unable to connect: ", ibm_db.conn_errormsg() )
# Out:
# Connected to database:  bludb as user:  xkk84284 on host:  1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud

# %%
dsn = (
    "DRIVER={0};"
    "DATABASE={1};"
    "HOSTNAME={2};"
    "PORT={3};"
    "PROTOCOL={4};"
    "UID={5};"
    "PWD={6};"
    "SECURITY={7};").format(dsn_driver, dsn_database, dsn_hostname, dsn_port, dsn_protocol, dsn_uid, dsn_pwd,dsn_security)
conn = ibm_db.connect(dsn, "", "")

# %%
pconn = ibm_db_dbi.Connection(conn)

# %%
df = pandas.read_sql('select ELEMENTARY__MIDDLE__OR_HIGH_SCHOOL from CHICAGO',pconn)
df
# Out:
# /tmp/ipykernel_6533/3664535758.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pandas.read_sql('select ELEMENTARY__MIDDLE__OR_HIGH_SCHOOL from CHICAGO',pconn)
#     ELEMENTARY__MIDDLE__OR_HIGH_SCHOOL
# 0                                   ES
# 1                                   ES
# 2                                   ES
# 3                                   ES
# 4                                   HS
# ..                                 ...
# 561                                 ES
# 562                                 ES
# 563                                 ES
# 564                                 ES
# 565                                 HS
#
# [566 rows x 1 columns]

# %%
df = pandas.read_sql('select * from CHICAGO',pconn)
df
# Out:
# /tmp/ipykernel_6533/1664103188.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pandas.read_sql('select * from CHICAGO',pconn)
#      SCHOOL_ID                                     NAME_OF_SCHOOL  \
# 0       610038                  Abraham Lincoln Elementary School
# 1       610281  Adam Clayton Powell Paideia Community Academy ...
# 2       610185                Adlai E Stevenson Elementary School
# 3       609993                    Agustin Lara Elementary Academy
# 4       610513                      Air Force Academy High School
# ..         ...                                                ...
# 561     610172                William T Sherman Elementary School
# 562     609844                 William W Carter Elementary School
# 563     610088                Wolfgang A Mozart Elementary School
# 564     609977               Woodlawn Community Elementary School
# 565     610392                 World Language Academy High School
#
#     ELEMENTARY__MIDDLE__OR_HIGH_SCHOOL         STREET_ADDRESS     CITY STATE  \
# 0                                   ES        615 W Kemper Pl  Chicago    IL
# 1                                   ES  7511 S South Shore Dr  Chicago    IL
# 2                                   ES     8010 S Kostner Ave  Chicago    IL
# 3                                   ES     4619 S Wolcott Ave  Chicago    IL
# 4                                   HS        3630 S Wells St  Chicago    IL
# ..                                 ...                    ...      ...   ...
# 561                                 ES         1000 W 52nd St  Chicago    IL
# 562                                 ES    5740 S Michigan Ave  Chicago    IL
# 563                                 ES      2200 N Hamlin Ave  Chicago    IL
# 564                                 ES     6657 S Kimbark Ave  Chicago    IL
# 565                                 HS     3120 S Kostner Ave  Chicago    IL
#
#      ZIP_CODE    PHONE_NUMBER  \
# 0       60614  (773) 534-5720
# 1       60649  (773) 535-6650
# 2       60652  (773) 535-2280
# 3       60609  (773) 535-4389
# 4       60609  (773) 535-1590
# ..        ...             ...
# 561     60609  (773) 535-1757
# 562     60637  (773) 535-0860
# 563     60647  (773) 534-4160
# 564     60637  (773) 535-0801
# 565     60623  (773) 535-4334
#
#                                                   LINK  \
# 0    http://schoolreports.cps.edu/SchoolProgressRep...
# 1    http://schoolreports.cps.edu/SchoolProgressRep...
# 2    http://schoolreports.cps.edu/SchoolProgressRep...
# 3    http://schoolreports.cps.edu/SchoolProgressRep...
# 4    http://schoolreports.cps.edu/SchoolProgressRep...
# ..                                                 ...
# 561  http://schoolreports.cps.edu/SchoolProgressRep...
# 562  http://schoolreports.cps.edu/SchoolProgressRep...
# 563  http://schoolreports.cps.edu/SchoolProgressRep...
# 564  http://schoolreports.cps.edu/SchoolProgressRep...
# 565  http://schoolreports.cps.edu/SchoolProgressRep...
#
#                         NETWORK_MANAGER  ... FRESHMAN_ON_TRACK_RATE__  \
# 0          Fullerton Elementary Network  ...                      NDA
# 1             Skyway Elementary Network  ...                      NDA
# 2             Midway Elementary Network  ...                      NDA
# 3           Pershing Elementary Network  ...                      NDA
# 4    Southwest Side High School Network  ...                     91.8
# ..                                  ...  ...                      ...
# 561                        AUSL Schools  ...                      NDA
# 562     Burnham Park Elementary Network  ...                      NDA
# 563        Fullerton Elementary Network  ...                      NDA
# 564     Burnham Park Elementary Network  ...                      NDA
# 565       West Side High School Network  ...                       76
#
#     X_COORDINATE Y_COORDINATE   LATITUDE  LONGITUDE COMMUNITY_AREA_NUMBER  \
# 0    1171699.458  1915829.428  41.924497 -87.644522                     7
# 1    1196129.985  1856209.466  41.760324 -87.556736                    43
# 2    1148427.165  1851012.215  41.747111 -87.731702                    70
# 3    1164504.290  1873959.199  41.809757 -87.672145                    61
# 4    1175177.622  1880745.126  41.828146 -87.632794                    34
# ..           ...          ...        ...        ...                   ...
# 561  1170500.817  1870373.159  41.799788 -87.650255                    61
# 562  1178101.365  1866810.123  41.789841 -87.622490                    40
# 563  1150644.396  1914368.955  41.920927 -87.721925                    22
# 564  1185825.188  1860883.579  41.773400 -87.594356                    42
# 565  1147521.302  1883405.128  41.836020 -87.734195                    30
#
#     COMMUNITY_AREA_NAME  WARD POLICE_DISTRICT                     LOCATION
# 0          LINCOLN PARK    43              18  (41.92449696, -87.64452163)
# 1           SOUTH SHORE     7               4  (41.76032435, -87.55673627)
# 2               ASHBURN    13               8  (41.74711093, -87.73170248)
# 3              NEW CITY    20               9    (41.8097569, -87.6721446)
# 4         ARMOUR SQUARE    11               9  (41.82814609, -87.63279369)
# ..                  ...   ...             ...                          ...
# 561            NEW CITY    16               9  (41.79978772, -87.65025483)
# 562     WASHINGTON PARK    20               2  (41.78984129, -87.62248974)
# 563        LOGAN SQUARE    35              25  (41.92092734, -87.72192541)
# 564            WOODLAWN     5               3  (41.77339962, -87.59435584)
# 565      SOUTH LAWNDALE    22              10  (41.83601953, -87.73419465)
#
# [566 rows x 78 columns]

# %%
df.describe(include='all')
# Out:
#             SCHOOL_ID                     NAME_OF_SCHOOL  \
# count      566.000000                                566
# unique            NaN                                566
# top               NaN  Abraham Lincoln Elementary School
# freq              NaN                                  1
# mean    609681.791519                                NaN
# std       8831.060946                                NaN
# min     400018.000000                                NaN
# 25%     609873.250000                                NaN
# 50%     610052.500000                                NaN
# 75%     610212.750000                                NaN
# max     610544.000000                                NaN
#
#        ELEMENTARY__MIDDLE__OR_HIGH_SCHOOL      STREET_ADDRESS     CITY STATE  \
# count                                 566                 566      566   566
# unique                                  3                 550        1     1
# top                                    ES  3120 S Kostner Ave  Chicago    IL
# freq                                  462                   4      566   566
# mean                                  NaN                 NaN      NaN   NaN
# std                                   NaN                 NaN      NaN   NaN
# min                                   NaN                 NaN      NaN   NaN
# 25%                                   NaN                 NaN      NaN   NaN
# 50%                                   NaN                 NaN      NaN   NaN
# 75%                                   NaN                 NaN      NaN   NaN
# max                                   NaN                 NaN      NaN   NaN
#
#             ZIP_CODE    PHONE_NUMBER  \
# count     566.000000             566
# unique           NaN             564
# top              NaN  (773) 534-1530
# freq             NaN               2
# mean    60629.727915             NaN
# std        20.248024             NaN
# min     60605.000000             NaN
# 25%     60618.000000             NaN
# 50%     60625.000000             NaN
# 75%     60639.000000             NaN
# max     60827.000000             NaN
#
#                                                      LINK  \
# count                                                 565
# unique                                                565
# top     http://schoolreports.cps.edu/SchoolProgressRep...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                      NETWORK_MANAGER  ... FRESHMAN_ON_TRACK_RATE__  \
# count                            566  ...                      566
# unique                            20  ...                       79
# top     Fullerton Elementary Network  ...                      NDA
# freq                              41  ...                      479
# mean                             NaN  ...                      NaN
# std                              NaN  ...                      NaN
# min                              NaN  ...                      NaN
# 25%                              NaN  ...                      NaN
# 50%                              NaN  ...                      NaN
# 75%                              NaN  ...                      NaN
# max                              NaN  ...                      NaN
#
#         X_COORDINATE  Y_COORDINATE    LATITUDE   LONGITUDE  \
# count   5.660000e+02  5.660000e+02  566.000000  566.000000
# unique           NaN           NaN         NaN         NaN
# top              NaN           NaN         NaN         NaN
# freq             NaN           NaN         NaN         NaN
# mean    1.163016e+06  1.885663e+06   41.841890  -87.677323
# std     1.605930e+04  3.285688e+04    0.090361    0.058390
# min     1.118114e+06  1.817242e+06   41.653674  -87.841052
# 25%     1.152166e+06  1.860248e+06   41.771866  -87.717152
# 50%     1.163553e+06  1.886889e+06   41.845521  -87.675878
# 75%     1.174256e+06  1.911652e+06   41.913584  -87.636059
# max     1.202811e+06  1.950960e+06   42.021064  -87.533007
#
#        COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME        WARD POLICE_DISTRICT  \
# count             566.000000                 566  566.000000      566.000000
# unique                   NaN                  77         NaN             NaN
# top                      NaN              AUSTIN         NaN             NaN
# freq                     NaN                  23         NaN             NaN
# mean               37.706714                 NaN   22.060071       11.710247
# std                21.584135                 NaN   13.645574        6.688582
# min                 1.000000                 NaN    1.000000        1.000000
# 25%                23.000000                 NaN   10.000000        7.000000
# 50%                31.500000                 NaN   21.000000       10.000000
# 75%                58.000000                 NaN   32.750000       17.000000
# max                77.000000                 NaN   50.000000       25.000000
#
#                            LOCATION
# count                           566
# unique                          550
# top     (41.83601953, -87.73419465)
# freq                              4
# mean                            NaN
# std                             NaN
# min                             NaN
# 25%                             NaN
# 50%                             NaN
# 75%                             NaN
# max                             NaN
#
# [11 rows x 78 columns]

# %% [markdown]
# # Question 1. Calculate the total number of students in each grade level.

# %%
q1 = pandas.read_sql(
  """
  SELECT
      `Elementary, Middle, or High School`,
      COUNT(*) as total_number_of_students
  FROM chicago
  GROUP BY `Elementary, Middle, or High School`;
  """,
pconn)
q1
# Out:
# /tmp/ipykernel_70554/512428430.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   qo = pandas.read_sql('select ELEMENTARY__MIDDLE__OR_HIGH_SCHOOL, count(*) as total_number_of_students from CHICAGO group by ELEMENTARY__MIDDLE__OR_HIGH_SCHOOL',pconn)
#   ELEMENTARY__MIDDLE__OR_HIGH_SCHOOL  TOTAL_NUMBER_OF_STUDENTS
# 0                                 ES                       462
# 1                                 HS                        93
# 2                                 MS                        11

# %% [markdown]
# # QUESTION 2.Find the top 5 student groups with the largest number and highest safety

# %%
q2 = pandas.read_sql(
  """
  SELECT
    NAME_OF_SCHOOL,SAFETY_SCORE,
    SAFETY_ICON
  FROM chicago
  WHERE SAFETY_SCORE not like \'%NONE%\'
  ORDER BY SAFETY_SCORE DESC LIMIT 5
  """
  ,pconn)
q2
# Out:
# /tmp/ipykernel_70554/2988197443.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   q2 = pandas.read_sql(
#                                  NAME_OF_SCHOOL  SAFETY_SCORE  SAFETY_ICON
# 0             Abraham Lincoln Elementary School            99  Very Strong
# 1   Edgar Allan Poe Elementary Classical School            99  Very Strong
# 2           Augustus H Burley Elementary School            99  Very Strong
# 3  Annie Keller Elementary Gifted Magnet School            99  Very Strong
# 4       Alexander Graham Bell Elementary School            99  Very Strong

# %% [markdown]
# # Question 3. Calculate average of AVERAGE_STUDENT_ATTENDANCE of 10 schools with least SAFETY_SCORE

# %%
q3 = pandas.read_sql(
    """
    SELECT ROUND(AVG(CAST(REPLACE(AVERAGE_STUDENT_ATTENDANCE, '%', '') AS DECIMAL(5, 2))),2) AS average_attendance
    FROM (
        SELECT 
            Name_OF_SCHOOL,
            AVERAGE_STUDENT_ATTENDANCE,
            SAFETY_SCORE
        FROM chicago
        ORDER BY SAFETY_SCORE
        LIMIT 10
    ) AS subquery;
    """, 
pconn
)
q3
# Out:
# /tmp/ipykernel_70554/227068513.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   qt = pandas.read_sql(
#    AVERAGE_ATTENDANCE
# 0               89.12

# %% [markdown]
# # Question 4. Find 10 High school with highest College_Eligibility__ score.

# %%
import pandas as pd

# SQL query to select the top 10 schools with the highest College_Eligibility_Score
q4 = pd.read_sql(
    """
    SELECT Name_OF_SCHOOL, CAST(College_Eligibility__ AS FLOAT) AS College_Eligibility_Score
    FROM chicago
    WHERE COLLEGE_ELIGIBILITY__ NOT LIKE '%NDA%'
    ORDER BY College_Eligibility_Score DESC
    LIMIT 10;
    """,
    pconn
)
q4
# Out:
# /tmp/ipykernel_70554/505405610.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   qf = pd.read_sql(
#                                       NAME_OF_SCHOOL  \
# 0          Northside College Preparatory High School
# 1      Walter Payton College Preparatory High School
# 2                 Whitney M Young Magnet High School
# 3      William Jones College Preparatory High School
# 4                Albert G Lane Technical High School
# 5              Northside Learning Center High School
# 6       Jacqueline B Vaughn Occupational High School
# 7                           Lincoln Park High School
# 8  Gwendolyn Brooks College Preparatory Academy H...
# 9     DeVry University Advantage Academy High School
#
#    COLLEGE_ELIGIBILITY_SCORE
# 0                       98.0
# 1                       96.4
# 2                       89.0
# 3                       83.3
# 4                       67.9
# 5                       66.7
# 6                       55.6
# 7                       53.6
# 8                       51.1
# 9                       40.6

# %%
! pip install openpyxl

# %%
! mamba install openpyxl==3.0.9 -y

# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library

# %%
! pip3 install folium==0.5.0
import folium

print('Folium installed and imported!')

# %%
# define the world map
world_map = folium.Map()

# display world map
world_map

# %% [markdown]
# # CHICAGO MAP

# %%
# define the Chicago map with a higher zoom level
chicago_map = folium.Map(location=[41.84969736, -87.6252787], zoom_start=12)

# display Chicago map
chicago_map

#save Chicago map into .html
chicago_map.save('chicago.html')

# %%
folium.Marker([42.01017628, -87.68446868])

# %% [markdown]
# #### Figure out all school destination

# %%
import folium

print('Folium installed and imported!')
# Out:
# Folium installed and imported!

# %%
# define the world map
world_map = folium.Map()

# display world map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#             &lt;style&gt; #map_bbf8ffea1330e24b514e17926d7286ac {
#                 position : relative;
#                 width : 100.0%;
#                 height: 100.0%;
#                 left: 0.0%;
#                 top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bbf8ffea1330e24b514e17926d7286ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#
#
#                 var bounds = null;
#
#
#             var map_bbf8ffea1330e24b514e17926d7286ac = L.map(
#                                   &#x27;map_bbf8ffea1330e24b514e17926d7286ac&#x27;,
#                                   {center: [0,0],
#                                   zoom: 1,
#                                   maxBounds: bounds,
#                                   layers: [],
#                                   worldCopyJump: false,
#                                   crs: L.CRS.EPSG3857
#                                  });
#
#
#
#             var tile_layer_14ceb85de0511aec45b0b4ed4822dc39 = L.tileLayer(
#                 &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#                 {
#   &quot;attribution&quot;: null,
#   &quot;detectRetina&quot;: false,
#   &quot;maxZoom&quot;: 18,
#   &quot;minZoom&quot;: 1,
#   &quot;noWrap&quot;: false,
#   &quot;subdomains&quot;: &quot;abc&quot;
# }
#                 ).addTo(map_bbf8ffea1330e24b514e17926d7286ac);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
loc = pd.read_sql('SELECT REPLACE(REPLACE(Location, \'(\', \'\'), \')\', \'\') as des FROM CHICAGO', pconn)
loc
# Out:
# /tmp/ipykernel_70554/2196685076.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   loc = pd.read_sql('SELECT REPLACE(REPLACE(Location, \'(\', \'\'), \')\', \'\') as des FROM CHICAGO', pconn)
#                            DES
# 0    41.92449696, -87.64452163
# 1    41.76032435, -87.55673627
# 2    41.74711093, -87.73170248
# 3      41.8097569, -87.6721446
# 4    41.82814609, -87.63279369
# ..                         ...
# 561  41.79978772, -87.65025483
# 562  41.78984129, -87.62248974
# 563  41.92092734, -87.72192541
# 564  41.77339962, -87.59435584
# 565  41.83601953, -87.73419465
#
# [566 rows x 1 columns]

# %%
kd = pd.read_sql('SELECT Latitude FROM Chicago',pconn)
vd = pd.read_sql('SELECT Longitude FROM Chicago',pconn)
# Out:
# /tmp/ipykernel_70554/1116018221.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   kd = pd.read_sql('select Latitude from Chicago',pconn)
# /tmp/ipykernel_70554/1116018221.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   vd = pd.read_sql('select Longitude from Chicago',pconn)

# %%
sl = """SELECT * FROM CHICAGO"""
df = pd.read_sql(sl,pconn)
from folium.plugins import MarkerCluster
chicago_map = folium.Map(location=[41.84969736, -87.6252787], zoom_start=12)


tooltip = 'Click me!'


df1 = df[['LATITUDE','LONGITUDE','NAME_OF_SCHOOL']]
# df2 = df[['LATITUDE','LONGITUDE']]
marker_cluster = MarkerCluster().add_to(chicago_map)
for index, row in df1.iterrows():
    latitude = row['LATITUDE']
    longitude = row['LONGITUDE']
    label = row['NAME_OF_SCHOOL']
    folium.Marker([latitude, longitude],
                popup=folium.Popup(label,parse_html=True,max_width='1000000%'),
                icon=folium.Icon(icon='glyphicon glyphicon-headphones',)).add_to(marker_cluster)

chicago_map.save('chicathanh.html')
chicago_map
# Out:
# /tmp/ipykernel_70554/2159734587.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sl,pconn)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#             &lt;style&gt; #map_9bb1c834b47afbe9a29f45d995367e54 {
#                 position : relative;
#                 width : 100.0%;
#                 height: 100.0%;
#                 left: 0.0%;
#                 top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9bb1c834b47afbe9a29f45d995367e54&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#
#
#                 var bounds = null;
#
#
#             var map_9bb1c834b47afbe9a29f45d995367e54 = L.map(
#                                   &#x27;map_9bb1c834b47afbe9a29f45d995367e54&#x27;,
#                                   {center: [41.84969736,-87.6252787],
#                                   zoom: 12,
#                                   maxBounds: bounds,
#                                   layers: [],
#                                   worldCopyJump: false,
#                                   crs: L.CRS.EPSG3857
#                                  });
#
#
#
#             var tile_layer_938dac2f9d7ddb7ed87960037c1f9847 = L.tileLayer(
#                 &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#                 {
#   &quot;attribution&quot;: null,
#   &quot;detectRetina&quot;: false,
#   &quot;maxZoom&quot;: 18,
#   &quot;minZoom&quot;: 1,
#   &quot;noWrap&quot;: false,
#   &quot;subdomains&quot;: &quot;abc&quot;
# }
#                 ).addTo(map_9bb1c834b47afbe9a29f45d995367e54);
#
#
#             var marker_cluster_83cc1da8520034b6e25feb9b7b49ef90 = L.markerClusterGroup({
#
#             });
#             map_9bb1c834b47afbe9a29f45d995367e54.addLayer(marker_cluster_83cc1da8520034b6e25feb9b7b49ef90);
#
#
#
#             var marker_28bb349f77b0d129f64662895d54bc14 = L.marker(
#                 [41.92449696,-87.64452163],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(marker_cluster_83cc1da8520034b6e25feb9b7b49ef90);
#
#
#
#                 var icon_357380e2b8f28408b9a9ad1b6caca554 = L.AwesomeMarkers.icon({
#                     icon: &#x27;glyphicon glyphicon-headphones&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;blue&#x27;,
#                     prefix: &#x27;glyphicon&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_28bb349f77b0d129f64662895d54bc14.setIcon(icon_357380e2b8f28408b9a9ad1b6caca554);
#
#
#             var popup_e1fb70c99661fe572f4d4dab2e64821e = L.popup({maxWidth: &#x27;1000000%&#x27;});
#
#
#                 var html_36445cd6c69db9d53b35bfd0e5363629 = $(&#x27;&lt;div id=&quot;html_36445cd6c69db9d53b35bfd0e5363629&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Abraham Lincoln Elementary School&lt;/div&gt;&#x27;)[0];
#                 popup_e1fb70c99661fe572f4d4dab2e64821e.setContent(html_36445cd6c69db9d53b35bfd0e5363629);
#
#
#             marker_28bb349f77b0d129f64662895d54bc14.bindPopup(popup_e1fb70c99661fe572f4d4dab2e64821e);
#
#
#
#
#
#             var marker_6529dcdf70bbc16032bc958e17a89d7c = L.marker(
#                 [41.76032435,-87.55673627],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(marker_cluster_83cc1da8520034b6e25feb9b7b49ef90);
#
#
#
#                 var icon_3e24a867ce5f40210fcedfd94539144d = L.AwesomeMarkers.icon({
#                     icon: &#x27;glyphicon glyphicon-headphones&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;blue&#x27;,
#                     prefix: &#x27;glyphicon&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_6529dcdf70bbc16032bc958e17a89d7c.setIcon(icon_3e24a867ce5f40210fcedfd94539144d);
#
#
#             var popup_75a4570827b2437d9bf613188807a254 = L.popup({maxWidth: &#x27;1000000%&#x27;});
#
#
#                 var html_8887022894c65550f4a1b14e268ce212 = $(&#x27;&lt;div id=&quot;html_8887022894c65550f4a1b14e268ce212&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adam Clayton Powell Paideia Community Academy Elementary School&lt;/div&gt;&#x27;)[0];
#                 popup_75a4570827b2437d9bf613188807a254.setContent(html_8887022894c65550f4a1b14e268ce212);
#
#
#             marker_6529dcdf70bbc16032bc958e17a89d7c.bindPopup(popup_75a4570827b2437d9bf613188807a254);
#
#
#
#
#
#             var marker_d5f948e6f51f7910ebeb71b1f76f9fea = L.marker(
#                 [41.74711093,-87.73170248],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(marker_cluster_83cc1da8520034b6e25feb9b7b49ef90);
#
#
#
#                 var icon_ac62e1942ffb6bee334e86c3a6287ec3 = L.AwesomeMarkers.icon({
#                     icon: &#x27;glyphicon glyphicon-headphones&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;blue&#x27;,
#                     prefix: &#x27;glyphicon&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_d5f948e6f51f7910ebeb71b1f76f9fea.setIcon(icon_ac62e1942ffb6bee334e86c3a6287ec3);
#
#
#             var popup_8ed605ac3408f8e845fb84654970a9a9 = L.popup({maxWidth: &#x27;1000000%&#x27;});

# %%
import folium
import pandas as pd

# Define the Chicago map with a higher zoom level
chicago_map = folium.Map(location=[41.84969736, -87.6252787], zoom_start=12)

# Assuming you have DataFrames 'kd' and 'vd' with latitude and longitude data
# Replace 'LATITUDE' and 'LONGITUDE' with your actual column names
url = "https://leafletjs.com/examples/custom-icons/{}".format
icon_image = url("leaf-red.png")
shadow_image = url("leaf-shadow.png")

icon = folium.CustomIcon(
    icon_image,
    icon_size=(38, 95),
    icon_anchor=(22, 94),
    shadow_image=shadow_image,
    shadow_size=(50, 64),
    shadow_anchor=(4, 62),
    popup_anchor=(-3, -76),
)
# Iterate through rows in 'kd' and 'vd' DataFrames and add markers
for index, row in kd.iterrows():
    latitude = row['LATITUDE']  # Replace 'LATITUDE' with your actual column name
    longitude = vd.iloc[index]['LONGITUDE']  # Replace 'LONGITUDE' with your actual column name

    # Create markers with latitude and longitude
    folium.Marker(location=[latitude, longitude]).add_to(chicago_map)

# Save the Chicago map to an HTML file
chicago_map.save('chicago.html')

# Display the Chicago map (if running in a Jupyter Notebook or interactive environment)
chicago_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#             &lt;style&gt; #map_6e16282356a8afc8ae6656a74e45429f {
#                 position : relative;
#                 width : 100.0%;
#                 height: 100.0%;
#                 left: 0.0%;
#                 top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6e16282356a8afc8ae6656a74e45429f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#
#
#                 var bounds = null;
#
#
#             var map_6e16282356a8afc8ae6656a74e45429f = L.map(
#                                   &#x27;map_6e16282356a8afc8ae6656a74e45429f&#x27;,
#                                   {center: [41.84969736,-87.6252787],
#                                   zoom: 12,
#                                   maxBounds: bounds,
#                                   layers: [],
#                                   worldCopyJump: false,
#                                   crs: L.CRS.EPSG3857
#                                  });
#
#
#
#             var tile_layer_80ae0a3727c665316b2f06b82d010256 = L.tileLayer(
#                 &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#                 {
#   &quot;attribution&quot;: null,
#   &quot;detectRetina&quot;: false,
#   &quot;maxZoom&quot;: 18,
#   &quot;minZoom&quot;: 1,
#   &quot;noWrap&quot;: false,
#   &quot;subdomains&quot;: &quot;abc&quot;
# }
#                 ).addTo(map_6e16282356a8afc8ae6656a74e45429f);
#
#
#
#             var marker_d787d3c0dffcc5d0cd26f54670cb3bee = L.marker(
#                 [41.92449696,-87.64452163],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(map_6e16282356a8afc8ae6656a74e45429f);
#
#
#
#             var marker_464b1519de63d939526ea4d46d27f7da = L.marker(
#                 [41.76032435,-87.55673627],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(map_6e16282356a8afc8ae6656a74e45429f);
#
#
#
#             var marker_b9f67b3d8b24f9439cff345359dffda4 = L.marker(
#                 [41.74711093,-87.73170248],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(map_6e16282356a8afc8ae6656a74e45429f);
#
#
#
#             var marker_ab822c2c7ad5d30ef36c483e66234abe = L.marker(
#                 [41.8097569,-87.6721446],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(map_6e16282356a8afc8ae6656a74e45429f);
#
#
#
#             var marker_69072ba1d460adcf6f35fcbc3e624a44 = L.marker(
#                 [41.82814609,-87.63279369],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(map_6e16282356a8afc8ae6656a74e45429f);
#
#
#
#             var marker_0d9e0c035be7cffd7067dee9d07b02a9 = L.marker(
#                 [41.9711433,-87.70962725],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(map_6e16282356a8afc8ae6656a74e45429f);
#
#
#
#             var marker_ce66f262dff8a3e380f094a4943c6a98 = L.marker(
#                 [41.94661693,-87.69105603],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(map_6e16282356a8afc8ae6656a74e45429f);
#
#
#
#             var marker_554f48f950849aa08244d9b5db5dfbd3 = L.marker(
#                 [41.90684338,-87.68304259],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(map_6e16282356a8afc8ae6656a74e45429f);
#
#
#
#             var marker_4247bff9dfb79838274de3160c0b05ba = L.marker(
#                 [41.93576106,-87.68052441],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(map_6e16282356a8afc8ae6656a74e45429f);
#
#
#
#             var marker_f873db147efcc93c9ed86633d8fea600 = L.marker(
#                 [41.97160605,-87.72464139],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(map_6e16282356a8afc8ae6656a74e45429f);
#
#
#
#             var marker_37f9ff3ced04501a1e6d3e1044d2de7a = L.marker(
#                 [41.94952795,-87.68605496],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(map_6e16282356a8afc8ae6656a74e45429f);
#
#
#
#             var marker_ecc941ff2e7df487c7d483d1ebd0d39e = L.marker(
#                 [41.81329195,-87.64338051],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(map_6e16282356a8afc8ae6656a74e45429f);
#
#
#
#             var marker_95bd7f4387add6a20ef6a29403c1ba1d = L.marker(
#                 [41.94524725,-87.67085683],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(map_6e16282356a8afc8ae6656a74e45429f);
#
#
#
#             var marker_ad724f7dc5310ec897ee8b37d59ccd8b = L.marker(
#                 [41.90672216,-87.69300325],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(map_6e16282356a8afc8ae6656a74e45429f);
#
#
#
#             var marker_709ae59ecdcadc4248a5587891a635d1 = L.marker(
#                 [41.68663682,-87.63359476],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(map_6e16282356a8afc8ae6656a74e45429f);
#
#
#
#             var marker_c6bffc3

# %%
ibm_db.close()
